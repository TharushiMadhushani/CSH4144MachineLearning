# %%
print("Hello world")
# Out:
# Hello world

# %%
x=5
print(x)
# Out:
# 5

# %%
x="Hello"
print(x)
# Out:
# Hello

# %%
x=int(5)
x=str("Hello")

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x=5.5
print(type(x))
# Out:
# <class 'float'>

# %%
x=3.22222222
print(type(x))
# Out:
# <class 'float'>

# %%
x=4.5555555555555555555555555555555555555555555555555555555555555555555555555555555555555555555
print(type(x))
# Out:
# <class 'float'>

# %%
x='c'
print(type(x))
# Out:
# <class 'str'>

# %%
x=4
y=2
add=x+y
sub=x-y
mul=x*y
div=x/y
print("addition:",add)
print("Subtraction:",sub)
print("Multiplication:",mul)
print("Division:",div)
# Out:
# addition: 6
# Subtraction: 2
# Multiplication: 8
# Division: 2.0

# %%
myclass=5
_myclass=5

#commands

# %%
age=6
Age=7
AGE=8
print(age,Age,AGE)
print(age+Age+AGE)
# Out:
# 6 7 8
# 21

# %%
x="Good"
def myfun():
    print(x)
myfun()
# Out:
# Good

# %%
a=2
b=12
if a>b:
    print("a is greater than b")
    
elif a==b:
    print("a and b are an equal")
    
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
#while loop
i=1
while i<6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#for loop
letters=["A","B","C","D"]
for x in letters:
    print(x)
# Out:
# A
# B
# C
# D

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
letters=["A","B","C","D"]
for x in letters:
    print(x)
    
    if x=="C":
        break
# Out:
# A
# B
# C

# %%
letters=["A","B","C","D"]
for x in letters:
    
    if x=="C":
        continue
        
print(x)
# Out:
# D

# %%
for x in range(1,6):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
letters=["A","B","C","D"]
numbers=[1,2,3,4,5]
for x in letters:
    for y in numbers:
        print(x,y)
# Out:
# A 1
# A 2
# A 3
# A 4
# A 5
# B 1
# B 2
# B 3
# B 4
# B 5
# C 1
# C 2
# C 3
# C 4
# C 5
# D 1
# D 2
# D 3
# D 4
# D 5

# %%
def myfun(fname):
    print("hi I am "+fname)
myfun("Tharushi")
# Out:
# hi I am Tharushi

# %%
def myfun(a,b):
    add=a+b
    sub=a-b
    mul=a*b
    div=a/b
    rem=a%b
    print("addition is :",add)
    print("subtraction is :",sub)
    print("multiplication is :",mul)
    print("division is :",div)
    print("remainder is :",rem)
myfun(4,2)
# Out:
# addition is : 6
# subtraction is : 2
# multiplication is : 8
# division is : 2.0
# remainder is : 0

# %%
from statistics import median,mode,mean,stdev
data=[1,2,3,4,5,6,7,8,9]

result=median(data)
print("Median: ",result)

print("Mean: ",mean(data))
print("Mode: ",mode(data))
print("Stdev: ",stdev(data))
# Out:
# Median:  5
# Mean:  5
# Mode:  1
# Stdev:  2.7386127875258306

# %%
from statistics import median,mode,mean,stdev
data=[90,67,78,23,56,86,96,56,45]

result=median(data)
print("Median: ",result)

print("Mean: ",mean(data))
print("Mode: ",mode(data))
print("Stdev: ",stdev(data))
# Out:
# Median:  67
# Mean:  66.33333333333333
# Mode:  56
# Stdev:  23.743420141167533
